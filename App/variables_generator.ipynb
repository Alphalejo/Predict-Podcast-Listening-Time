# %%
import pandas as pd
import json

# %%
df = pd.read_csv('../Data/processed/Viz_df.csv')
df
# Out:
#             id  Episode_Title  Episode_Length_minutes  \
# 0       202844             30                  119.97
# 1       110926             57                   62.57
# 2       200533             93                   99.12
# 3       285483             30                   91.05
# 4        79612             26                   61.42
# ...        ...            ...                     ...
# 599993  259180             86                   63.41
# 599994  365840             80                   61.19
# 599995  131933             55                   19.40
# 599996  671157             69                   17.51
# 599997  121959             53                   54.11
#
#         Host_Popularity_percentage  Guest_Popularity_percentage  \
# 0                            64.21                        17.93
# 1                            27.22                        50.84
# 2                            82.95                        93.62
# 3                            99.51                        13.44
# 4                            23.48                         5.69
# ...                            ...                          ...
# 599993                       20.34                        67.59
# 599994                       38.87                         0.83
# 599995                       39.77                        52.85
# 599996                       92.29                        57.35
# 599997                       53.40                        22.20
#
#         Number_of_Ads Episode_Sentiment  Guest_Popularity_missing  \
# 0                 0.0          Negative                         0
# 1                 1.0          Positive                         0
# 2                 1.0          Negative                         0
# 3                 3.0           Neutral                         0
# 4                 1.0          Negative                         0
# ...               ...               ...                       ...
# 599993            2.0           Neutral                         0
# 599994            0.0           Neutral                         0
# 599995            1.0          Negative                         0
# 599996            0.0           Neutral                         0
# 599997            3.0          Positive                         0
#
#         Listening_Time_minutes  prediction       Genre  \
# 0                     57.67601   99.824983      Sports
# 1                     48.82398   47.413588   Lifestyle
# 2                     82.95502   76.563204        News
# 3                     71.68635   70.170154      Sports
# 4                     50.45880   50.319279   Lifestyle
# ...                        ...         ...         ...
# 599993                32.06549   37.200416       Music
# 599994                53.73476   50.997901       Music
# 599995                13.09288   12.820011      Health
# 599996                13.36094   12.357595        News
# 599997                29.30020   37.787504  Technology
#
#         Publication_day_number Publication_day  Publication_time_hour  \
# 0                            5        Saturday                      1
# 1                            4          Friday                      9
# 2                            1         Tuesday                      9
# 3                            3        Thursday                     20
# 4                            0          Monday                     15
# ...                        ...             ...                    ...
# 599993                       6          Sunday                      1
# 599994                       6          Sunday                      9
# 599995                       6          Sunday                      9
# 599996                       4          Friday                     20
# 599997                       1         Tuesday                     20
#
#        Publication_time      Podcast_Name
# 0                 Night          Game Day
# 1               Morning  Lifestyle Lounge
# 2               Morning       World Watch
# 3               Evening    Sports Central
# 4             Afternoon   Fashion Forward
# ...                 ...               ...
# 599993            Night       Sound Waves
# 599994          Morning         Tune Time
# 599995          Morning     Fitness First
# 599996          Evening      Daily Digest
# 599997          Evening    Digital Digest
#
# [599998 rows x 16 columns]

# %%
podcast_names = df.Podcast_Name.unique()

# %%
with open('./data/podcast_names.json', 'w') as f:
    json.dump(podcast_names.tolist(), f)

# %%
df.Episode_Length_minutes.mean()
# Out:
# np.float64(64.51463925737754)

# %%
df.Episode_Title.describe()
# Out:
# count    599998.000000
# mean         51.425735
# std          28.081941
# min           1.000000
# 25%          28.000000
# 50%          52.000000
# 75%          75.000000
# max         100.000000
# Name: Episode_Title, dtype: float64

# %%
df.Host_Popularity_percentage.mean()
# Out:
# np.float64(59.84419946470655)

# %%
df.Number_of_Ads.describe()
# Out:
# count    599998.000000
# mean          1.348176
# std           1.152937
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           2.000000
# max         103.910000
# Name: Number_of_Ads, dtype: float64

# %%
df.Genre.describe()
# Out:
# count     599998
# unique        10
# top       Sports
# freq       70301
# Name: Genre, dtype: object

# %%
genres = df.Genre.unique()
with open('./data/genres.json', 'w') as g:
    json.dump(genres.tolist(), g)

# %%
days = {
    'Monday': 0,
    'Tuesday': 1,
    'Wednesday': 2,
    'Thursday': 3,
    'Friday': 4,
    'Saturday': 5,
    'Sunday': 6
}

with open('./data/days.json', 'w') as f:
    json.dump(days, f)

# %%
publication_time = {
    'Morning': 9,
    'Afternoon': 15,
    'Evening': 20,
    'Night': 1
}

with open('./data/publication_time.json', 'w') as f:
    json.dump(publication_time, f)

# %%
encoded_df = pd.read_csv('../Data/processed/encoded_df.csv')
encoded_df
# Out:
#             id  Episode_Title  Episode_Length_minutes  \
# 0       202844             30                  119.97
# 1       110926             57                   62.57
# 2       200533             93                   99.12
# 3       285483             30                   91.05
# 4        79612             26                   61.42
# ...        ...            ...                     ...
# 599993  259180             86                   63.41
# 599994  365840             80                   61.19
# 599995  131933             55                   19.40
# 599996  671157             69                   17.51
# 599997  121959             53                   54.11
#
#         Host_Popularity_percentage  Guest_Popularity_percentage  \
# 0                            64.21                        17.93
# 1                            27.22                        50.84
# 2                            82.95                        93.62
# 3                            99.51                        13.44
# 4                            23.48                         5.69
# ...                            ...                          ...
# 599993                       20.34                        67.59
# 599994                       38.87                         0.83
# 599995                       39.77                        52.85
# 599996                       92.29                        57.35
# 599997                       53.40                        22.20
#
#         Number_of_Ads  Episode_Sentiment  Guest_Popularity_missing  \
# 0                 0.0                 -1                         0
# 1                 1.0                  1                         0
# 2                 1.0                 -1                         0
# 3                 3.0                  0                         0
# 4                 1.0                 -1                         0
# ...               ...                ...                       ...
# 599993            2.0                  0                         0
# 599994            0.0                  0                         0
# 599995            1.0                 -1                         0
# 599996            0.0                  0                         0
# 599997            3.0                  1                         0
#
#         Genre_encoded  Listening_Time_minutes  Time_sin  Time_cos   Day_sin  \
# 0           44.913404                57.67601  0.258819  0.965926 -0.974928
# 1           45.440905                48.82398  0.707107 -0.707107 -0.433884
# 2           44.371825                82.95502  0.707107 -0.707107  0.781831
# 3           44.913404                71.68635 -0.866025  0.500000  0.433884
# 4           45.440905                50.45880 -0.707107 -0.707107  0.000000
# ...               ...                     ...       ...       ...       ...
# 599993      46.533255                32.06549  0.258819  0.965926 -0.781831
# 599994      46.533255                53.73476  0.707107 -0.707107 -0.781831
# 599995      45.819181                13.09288  0.707107 -0.707107 -0.781831
# 599996      44.371825                13.36094 -0.866025  0.500000 -0.433884
# 599997      45.723748                29.30020 -0.866025  0.500000  0.781831
#
#          Day_cos  Podcast_Encoded
# 0      -0.222521        43.980881
# 1      -0.900969        45.628020
# 2       0.623490        43.996397
# 3      -0.900969        41.702596
# 4       1.000000        45.239931
# ...          ...              ...
# 599993  0.623490        44.461635
# 599994  0.623490        47.007739
# 599995  0.623490        45.873295
# 599996 -0.900969        45.814585
# 599997  0.623490        44.778224
#
# [599998 rows x 15 columns]

# %%
lenght = 65
host_popularity = 60
guest_popularity = 52.51  # Average Popularity when no guest is present
missing_guest = 1
podcast = 'Game Day'
title = 1
genre = 'News'
ads = 1
sentiment_raw = 'Neutral'
publication_day = 2
publication_time = 12

# %%
sentiment_map = {
    'Negative': -1,
    'Neutral': 0,
    'Positive': 1
}

sentiment = sentiment_map[sentiment_raw]

# %%
sentiment
# Out:
# 0

# %%
genre_map = {
    'Business': 45.55244226723161,
    'Comedy': 44.48775637598833,
    'Education': 45.69957544537044, 
    'Health': 45.81918055381969, 
    'Lifestyle': 45.4409049194452, 
    'Music': 46.533255061929985, 
    'News': 44.37182458341537, 
    'Sports': 44.913403840628156, 
    'Technology': 45.72374847377965, 
    'True Crime': 45.99179846445972 
}

# %%
import numpy as np

# Encoding for  hours (0-23)
Time_sin = np.sin(2 * np.pi * publication_time / 24)
Time_cos = np.cos(2 * np.pi * publication_time / 24)

# encoding for days (0-6)
Day_sin = np.sin(2 * np.pi * publication_day / 7)
Day_cos = np.cos(2 * np.pi * publication_day / 7)

# %%
print(Time_sin, Time_cos, Day_sin, Day_cos)
# Out:
# 1.2246467991473532e-16 -1.0 0.9749279121818236 -0.22252093395631434
